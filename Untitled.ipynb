# %%
# Cell 1
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# Cell 2
train_path = r"C:\Users\dell\Downloads\Rice_nutrition_analysis\train"

# %%
# Cell 3
for root, dirs, files in os.walk(train_path):
    for file in files:
        if file.endswith((".avif", ".webp")):
            os.remove(os.path.join(root, file))
            print("Deleted:", file)

print("Dataset cleaned")
# Out:
# Dataset cleaned

# %%
# Cell 4
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 87 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.

# %%
# Cell 5
print("Classes:", train_data.class_indices)
# Out:
# Classes: {'basmati': 0, 'brown': 1, 'red': 2, 'white': 3}

# %%
# Cell 6
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(train_data.num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 30, 30, 64)          │               0 │
# ...

# %%
# Cell 7
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Cell: CLEAN DATASET COMPLETELY
from PIL import Image
import os

train_path = r"C:\Users\dell\Downloads\Rice_nutrition_analysis\train"

deleted = 0

for root, dirs, files in os.walk(train_path):
    for file in files:
        file_path = os.path.join(root, file)
        
        # Remove AVIF / WEBP
        if file.lower().endswith((".avif", ".webp")):
            os.remove(file_path)
            print("Deleted (format):", file)
            deleted += 1
        
        else:
            # Check corrupted images
            try:
                img = Image.open(file_path)
                img.verify()   # check image validity
            except:
                os.remove(file_path)
                print("Deleted (corrupt):", file)
                deleted += 1

print("✅ Total removed:", deleted)
# Out:
# ✅ Total removed: 0

# %%
# Check again
for root, dirs, files in os.walk(train_path):
    for file in files:
        if file.endswith((".avif", ".webp")):
            print("❌ Still exists:", file)

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 87 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.

# %%
# Cell 8 (SAFE DATA LOADER)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from PIL import Image

train_path = r"C:\Users\dell\Downloads\Rice_nutrition_analysis\train"

# Remove bad images automatically
def remove_bad_images(folder):
    for root, dirs, files in os.walk(folder):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                img = Image.open(file_path)
                img.verify()
            except:
                os.remove(file_path)
                print("Removed bad image:", file)

remove_bad_images(train_path)

# Create generator
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_data = datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=16,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=16,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 87 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.

# %%
# IMPORTANT CELL (RUN THIS BEFORE TRAINING)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Dataset path
train_path = r"C:\Users\dell\Downloads\Rice_nutrition_analysis\train"

# ✅ Data Augmentation (IMPORTANT)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load data
train_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    train_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# ✅ PRINT CLASS ORDER (VERY IMPORTANT)
print("Class Indices:", train_data.class_indices)

# Save class order
class_names = list(train_data.class_indices.keys())

# ✅ Improved CNN Model
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(256, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(len(class_names), activation='softmax'))

# Compile
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Train (increase epochs)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=25
)

# Save model
model.save("cnn_model.h5")

# ✅ Save class labels
import json
with open("classes.json", "w") as f:
    json.dump(class_names, f)

print("✅ Model & classes saved")
# Out:
# Found 87 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.
# Class Indices: {'basmati': 0, 'brown': 1, 'red': 2, 'white': 3}
# Epoch 1/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.2989 - loss: 1.3977 - val_accuracy: 0.4737 - val_loss: 1.1730
# Epoch 2/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4368 - loss: 1.1480 - val_accuracy: 0.4737 - val_loss: 0.8810
# Epoch 3/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4828 - loss: 0.9262 - val_accuracy: 0.6316 - val_loss: 0.7342
# Epoch 4/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4598 - loss: 0.9552 - val_accuracy: 0.5263 - val_loss: 0.8650
# Epoch 5/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.4828 - loss: 0.8380 - val_accuracy: 0.5789 - val_loss: 0.7046
# Epoch 6/25
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 964ms/step - accuracy: 0.4943 - loss: 0.8383 - val_accuracy: 0.4737 - val_loss: 0.7401
# Epoch 7/25
# ...

# %%
# Cell 9
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %%
# Cell 10
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
# Cell 11
model.save("cnn_model.h5")
print("✅ Model Saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model Saved

# %%
import os

os.chdir(r"C:\Users\dell\Downloads\Rice_nutrition_analysis")
print("Changed to:", os.getcwd())
# Out:
# Changed to: C:\Users\dell\Downloads\Rice_nutrition_analysis

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'app.py', 'classes.json', 'cnn_model.h5', 'data', 'static', 'templates', 'test', 'train', 'Untitled.ipynb']

# %%
import cv2
import numpy as np

img_path = "3.jpg"   # simple path

img = cv2.imread(img_path)

if img is None:
    print("Image not loaded")
else:
    img = cv2.resize(img, (128,128))
    img = img / 255.0
    img = np.reshape(img, (1,128,128,3))

    prediction = model.predict(img)

    classes = list(train_data.class_indices.keys())
    print("Prediction:", classes[np.argmax(prediction)])
# Out:
# Image not loaded
